# %%
diccionario={"nombre": "raul",
            "apellido": "gonzales",
            "edad": 26 ,
             }
diccionario["nombre"]="hugo"#agregar datos
print(diccionario["nombre"])
print(diccionario.keys())#devuelve claves
print(diccionario.values())#devielve valores dentro de la clave
print(diccionario.items())#devuelve el valor y las claves juntas
diccionario.popitem()#elmina el ultimo elmento
print(diccionario.items())
del diccionario["apellido"]# elimina el valor o key elegido
print(diccionario)

for valor in diccionario.values():
    print(valor)
for clave in diccionario.keys():
    print(clave)
for clave, valor in diccionario.items():
    print(clave,valor)
# Out:
# hugo
# dict_keys(['nombre', 'apellido', 'edad'])
# dict_values(['hugo', 'gonzales', 26])
# dict_items([('nombre', 'hugo'), ('apellido', 'gonzales'), ('edad', 26)])
# dict_items([('nombre', 'hugo'), ('apellido', 'gonzales')])
# {'nombre': 'hugo'}
# hugo
# nombre
# nombre hugo

# %% [markdown]
# Challenge 1 🤺 10m
# Escribir un programa que cree un diccionario vacío y lo vaya llenado con información sobre una persona (por ejemplo nombre, edad, sexo, teléfono, correo electrónico, etc.) que se le pida al usuario.
#
# Cada vez que se añada un nuevo dato debe imprimirse el contenido del diccionario.

# %% [markdown]
# #crear el diccionario
# #pedir al usuario ingresar sus datos y que vallan llenando con claves
# #se tiene que repetir hasta completar el diccionario

# %%
informe={}

nombre=input("ingrese su nombre")
informe["nombre:"]=nombre
print(informe)
apellido=input("ingrese su apellido")
informe["apellido:"]=apellido
print(informe)
numero_ci=int(input("ingrese su cedula de indentidad"))
informe["Cedula:"]=numero_ci
print(informe)
# Out:
# {'nombre:': 'Hugo'}
# {'nombre:': 'Hugo', 'apellido:': 'Ramirez'}
# {'nombre:': 'Hugo', 'apellido:': 'Ramirez', 'Cedula:': 6316391}

# %%
informe_automatico={}
cantidad_informe=int(input("ingrese la cnatidad de datos que desea ingresar"))

for i in range(cantidad_informe):
    clave=input("ingrese su clave")  
    valor=input("ingrese un valor")
    informe_automatico[clave]=valor
    print(informe_automatico)
# Out:
# {'nombre': 'hugo', 'apellido': 'ramirez', 'ciudad': 'luque', 'barrio': 'ykuadure'}

# %% [markdown]
# crear una tarjeta personal. El usuario (mediante input) puede elegir:
#
# Crear datos nuevos
# Modificar datos
# Eliminar datos

# %%
tarjeta={}

while True:
    accion=int(input("que desea realizar,1=crear,2=modificar,3=eliminar "))
  
    if accion==1:
        clave_1=input("ingrese la clave")
        valor_1=input("ingrese el valor para la clave")
        tarjeta[clave_1]=valor_1
        print(tarjeta)
    elif accion==2:
        print("los valores que podes modificar son son")
        print(tarjeta.items())
        clave_1=input("ingrese la clave a cambiar")
        modificacion=input("ingrese el valor nuevo")
        tarjeta[clave_1]=modificacion
        print(tarjeta)
    elif accion==3:
        print("los valores que podes eliminar son")
        print(tarjeta.keys())
        clave_1=input("ingresa el valor a eliminar")
        del tarjeta[clave_1]
        print(tarjeta)
    parar=input("si desea salir ingrese si sino ingrese no")
    if parar=="si":
        break
# Out:
# {'nombre': 'hugo'}
# {'nombre': 'hugo', 'apellido': 'ramirez'}
# {'nombre': 'hugo', 'apellido': 'ramirez', 'ciudad': 'luque'}
# los valores que podes eliminar son
# dict_keys(['nombre', 'apellido', 'ciudad'])
# {'nombre': 'hugo', 'apellido': 'ramirez'}

# %% [markdown]
# Challenge 3 🤺
# Crear una agenda de contactos. El usuario puede elegir:
#
# Mostrar los contactos
# Crear contacto
# Modificar datos del contacto

# %%
contactos={"Mbopi": "0974787878", "RamiH": "0974988383", "Pablito" : "0982834545"}
def telefono():
    while True:
        acciones=int(input("ingrese 1=mostrar,2=crear contactos, 3=modificar contacto"))
        if acciones==1:
            print(contactos)
        elif acciones==2:
            nombre_n=input("ingrese un nombre")
            contacto=int(input("ingrese numero de contacto"))
            contactos[nombre_n]=contacto
            print(contactos)
        elif acciones==3:
            print("los contactosa modificar son:", contactos)
            nombre_m=input("ingrese la clave a modificar")
            contacto=int(input("ingrese numero de contacto"))
            contactos[nombre_m]=contacto
            print(contactos)
        parar=input('ingrese si  desea parar si sino no')
        if parar=="si":
            break
telefono()
# Out:
# {'Mbopi': '0974787878', 'RamiH': '0974988383', 'Pablito': '0982834545'}
# {'Mbopi': '0974787878', 'RamiH': '0974988383', 'Pablito': '0982834545', 'pablo': 974}
# los contactosa modificar son: {'Mbopi': '0974787878', 'RamiH': '0974988383', 'Pablito': '0982834545', 'pablo': 974}
# {'Mbopi': 974565656, 'RamiH': '0974988383', 'Pablito': '0982834545', 'pablo': 974}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 21
#      19         if parar=="si":
#      20             break
# ---> 21 telefono()
#
# Cell In[49], line 4, in telefono()
#       2 def telefono():
#       3     while True:
# ----> 4         acciones=int(input("ingrese 1=mostrar,2=crear contactos, 3=modificar contacto"))
#       5         if acciones==1:
#       6             print(contactos)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
class Dog:
    #atributos
    cabeza=1
    patas=4
    cola=1
#Creando un objeto o instancia
firulais=Dog()
charlie=Dog()
print(firulais.cabeza)
print(firulais.cola)
# Out:
# 1
# 1

# %%
class Pokemon:
    especie="electrico"
    def __init__(self, nombre, poderes, habilidad):
        self.nombre=nombre
        self.poderes=poderes
        self.habilidad=habilidad
pikachu=Pokemon("pikachu","impactrueno,bola voltio,velocidad extrema,ataque rapido","intimidacion")
print("Tu pokemon de tipo elctrico es:")
print(pikachu.nombre)
print("los movimientos del pokemon son:")
print(pikachu.poderes)
print("la habilidad del tu pokemon es:")
print(pikachu.habilidad)
# Out:
# Tu pokemon de tipo elctrico es:
# pikachu
# los movimientos del pokemon son:
# impactrueno,bola voltio,velocidad extrema,ataque rapido
# la habilidad del tu pokemon es:
# intimidacion

# %%
class Perro:
    especie="el mejor amigo del hombre"
    def __init__(self, nombre, color):
        self.nombre=nombre
        self.color=color
perro1=Perro("Nala","Marron")
perro2=Perro("Charlie","blanco")

print(f"Este perro se llama:{perro1.nombre} es de color:{perro1.color}, y su especio es:{perro1.especie}") 
print(f"Este perro se llama:{perro2.nombre} es de color:{perro2.color}, y su especio es:{perro2.especie}")
# Out:
# Este perro se llama:Nala es de color:Marron, y su especio es:el mejor amigo del hombre
# Este perro se llama:Charlie es de color:blanco, y su especio es:el mejor amigo del hombre

# %%
class Hero:
    tipo="mutante elemental de nivel omega"
    def __init__(self, apodo,poderes,color_traje):
        self.apodo=apodo
        self.poderes=poderes
        self.colo_traje=color_traje
    def hielo(self,grados ):
        print(f"disminuir la temperatura en{grados}:grados")
    def fuego(self, grados):
        print(f"elevar la temperatura en{grados}:grados")
hero1=Hero("Ice Man","Controla el hielo","Negro")
print(hero1.apodo,hero1.poderes,"es un",hero1.tipo)
hero1.hielo(-120)
# Out:
# Ice Man Controla el hielo es un mutante elemental de nivel omega
# disminuir la temperatura en-120:grados

# %%
class Loro:
    def __init__(self, nombre):
        self.nombre=nombre
    def hablar(self, frase):
        print(f"Mi loro {self.nombre} siempres grita {frase} cuando paraguay mete gol")
    def movimiento(self, accion):
        print(f"Mi loro {self.nombre} siempre {accion} cuando se asusta")
loro1=Loro("Pancho")
loro1.hablar("Paraguay Campeon")
loro1.movimiento("vuela al techo")
# Out:
# Mi loro Pancho siempres grita Paraguay Campeon cuando paraguay mete gol
# Mi loro Pancho siempre vuela al techo cuando se asusta

# %%
class Mom:
    apelido="Gomez"
    def __init__(self,nombre, color_ojos, cabello ):
        self.nombre=nombre
        self.color_ojos=color_ojos
        self.cabello=cabello 

class Hija(Mom):
        def mostrar_h(self):
             print(self.nombre,self.cabello,self.color_ojos,self.apelido)
class Nieta(Hija):
        def mostrar_n(self):
             print(self.nombre,self.cabello,self.color_ojos,self.apelido)
hija1 = Hija("pabla", "Verdes", "rulos")
nieta=Nieta("pablita", "azules", "Rulos")
hija1.mostrar_h()
nieta.mostrar_n()
# Out:
# pabla rulos Verdes Gomez
# pablita Rulos azules Gomez

# %% [markdown]
# Challenge 4 🤺 - 20 min
# Crear dos personajes de una historia que se representen a traves de clases. Ejemplo: Un hereo y un villano.
# Cada personaje debe tener poderes o acciones diferentes. Y deben presentarse en una frase.
#
# Ejemplo: Yo me llamo pepito y tengo super fuerza
# Ejemplo: Yo me llamo juanito y puedo volar

# %%
class personajes:
    def __init__(self, apodo, poderes, aspecto):
        self.apodo=apodo
        self.poderes=poderes
        self.aspecto=aspecto
    def presentacion_1(self):
        print(f"Me presento soy {self.apodo} , tengo la capacidad de {self.poderes} todo el planeta")
    def presentacion_2(self):
        print(f"Me presento soy {self.apodo} , tengo la capacidad de {self.poderes} todo el planeta")
personaje1=personajes("sol", "ilumnar", "soy alto con un traje amarrilo soy la estrella mas brillante del lugar")
personaje2=personajes("luna", "oscurecer", "Soy un enano con traje negro las sombras son mi hogar")
personaje1.presentacion_1()
print(personaje1.aspecto)
print("-----------------------")
personaje2.presentacion_2()
print(personaje2.aspecto)
# Out:
# Me presento soy sol , tengo la capacidad de ilumnar todo el planeta
# soy alto con un traje amarrilo soy la estrella mas brillante del lugar
# -----------------------
# Me presento soy luna , tengo la capacidad de oscurecer todo el planeta
# Soy un enano con traje negro las sombras son mi hogar
