# %%
print("PEPE")
# Out:
# PEPE

# %% [markdown]
# crear un funcion que escriba la variable palabra

# %%
palabra=input("ingrese una palabra")
def imprimir():
    print(palabra)
imprimir()
# Out:
# pablo

# %%
def imprimir_suma():
    num1=int(input("ingrese un numero"))
    print("numero 1=",num1)
    num2=int(input("ingrese un numero"))
    print("numero 2=",num2)
    suma=num1+num2
    print("resultado de la suma:",num1,"+",num2,"=",suma)

imprimir_suma()
# Out:
# numero 1= 4
# numero 2= 5
# resultado de la suma: 4 + 5 = 9

# %%
def realizar_suma(n1, n2):
    sum=n1+n2
    print("resultado de la suma:",n1,"+",n2,"=",sum)
realizar_suma(2, 10)
# Out:
# resultado de la suma: 2 + 10 = 12

# %%
def realizar_suma(n1, n2):
   print("resultado de la suma:",n1,"+",n2,"=",n1+n2)
realizar_suma(2, 10)
# Out:
# resultado de la suma: 2 + 10 = 12

# %%
cc1=input("ingrese una letra")
cc2=input("ingrese una letra")

def comparacion (c1,c2):
    
    if c1==c2:
        print("las letras son iguales")
    else:
        print("las letras son distintas" ,c1,",",c2)
comparacion(cc1,cc2)
# Out:
# las letras son distintas a , b

# %%
def sumar(n1,n2):
    r_sum=n1+n2
    return r_sum
resul=sumar()#tenes que guardar si o si en una variable para que el dato sea reconocido.
print(resul)
# Out:
# 4

# %%
letra_e=input("ingreseuna palabra")
numero_e=int(input("ingrese un numero"))
def problema(letra, numero):
    comparacion=len(letra)
    if comparacion==numero:
        return(True)
    else:
        return(False)

caja=problema(letra_e, numero_e)
print(caja)
# Out:
# tienen la misma longitud
# True

# %% [markdown]
# Crear función que revise si una palabra contiene una letra. En caso de que la contenga, retornar la letra entre corchetes []. De lo contrario, retornar solo la letra.

# %%
palabra_c="p"
def revisa():
    palabra=input("ingrese una palabra")
    if palabra_c in palabra:
        return("[",palabra_c,"]")
    else:
        return(palabra_c)
    
        
caja=revisa()
print(caja)
# Out:
# ('[', 'p', ']')

# %%
palabra_ingresadas=[]
c=0
while c<3:
    p_elegida=input("ingrese una palabra")
    p_lista=list(p_elegida)
    palabra_ingresadas.append(p_lista)
    print(palabra_ingresadas, " ")
    c+=1
# Out:
# [['p', 'o', 'l', 'l', 'o']]
# [['p', 'o', 'l', 'l', 'o'], ['p', 'o', 'l', 'l', 'a']]
# [['p', 'o', 'l', 'l', 'o'], ['p', 'o', 'l', 'l', 'a'], ['p', 'o', 'l', 'l', 'o', 'n']]

# %%
p1="holis"
p2="hello"
p3="hallo"
lista=[]

lista=list(p1),list(p2),list(p3)
def listas_listas():
    for c in range (3):
        print(lista[c])
        
        
listas_listas()
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']
